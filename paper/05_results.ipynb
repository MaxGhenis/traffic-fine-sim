# %% [markdown]
# # Results
#
# This section presents our main findings on the welfare effects of income-based versus flat traffic fine systems.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Import our simulation framework
from traffic_fines.core import Agent, Society, FlatFine, IncomeBasedFine, WelfareOptimizer
from traffic_fines.utils.parameters import DEFAULT_PARAMS

# Set random seed for reproducibility
np.random.seed(42)

# Set style for figures
plt.rcParams['figure.dpi'] = 150
plt.rcParams['font.size'] = 11

# %% [markdown]
# ## Baseline Calibration
#
# We calibrate our model using Finnish institutional data:
# - Mean income: €45,000 (Finnish median)
# - VSL: €3.6M (EU recommendation for Finland)
# - Labor disutility parameter calibrated to match labor supply elasticity of ~0.25

# %%
# Generate income distribution
n_agents = 100
mean_wage = 25.0  # EUR/hour
wage_std = 10.0

wages = np.random.lognormal(
    mean=np.log(mean_wage) - 0.5 * (wage_std/mean_wage)**2,
    sigma=wage_std/mean_wage,
    size=n_agents
)
wages = np.clip(wages, 10, 150)  # Reasonable bounds

# Create agents with calibrated parameters
labor_disutility = 25.0  # Calibrated for interior labor supply
speeding_utility = 0.5
vsl = 100_000  # Lower VSL for interior speeding solutions

agents_flat = [Agent(wage=w, labor_disutility=labor_disutility, 
                     speeding_utility=speeding_utility, vsl=vsl) for w in wages]
agents_ib = [Agent(wage=w, labor_disutility=labor_disutility,
                   speeding_utility=speeding_utility, vsl=vsl) for w in wages]

print(f"Generated {n_agents} agents with wages €{wages.min():.0f} - €{wages.max():.0f}/hour")
print(f"Mean wage: €{wages.mean():.0f}/hour")
print(f"Median wage: €{np.median(wages):.0f}/hour")

# %% [markdown]
# ## Welfare Comparison
#
# We compare welfare under flat fines versus income-based fines.

# %%
# Run simulations with comparable fine structures
flat_fine = FlatFine(amount=500.0)
income_fine = IncomeBasedFine(rate=0.005)  # ~500 at 100k income

society_flat = Society(agents_flat, flat_fine, tax_rate=0.3)
society_ib = Society(agents_ib, income_fine, tax_rate=0.3)

results_flat = society_flat.simulate(max_iterations=20)
results_ib = society_ib.simulate(max_iterations=20)

print("\n=== WELFARE COMPARISON ===")
print(f"\nFlat Fine System:")
print(f"  Total Welfare: {results_flat['total_utility']:.2f}")
print(f"  Avg Speeding: {results_flat['avg_speeding']:.4f}")
print(f"  Total Fines: €{results_flat['total_fines']:,.0f}")

print(f"\nIncome-Based Fine System:")
print(f"  Total Welfare: {results_ib['total_utility']:.2f}")
print(f"  Avg Speeding: {results_ib['avg_speeding']:.4f}")
print(f"  Total Fines: €{results_ib['total_fines']:,.0f}")

welfare_diff = results_flat['total_utility'] - results_ib['total_utility']
print(f"\nWelfare Difference (Flat - Income-Based): {welfare_diff:.2f}")
print(f"Preferred System: {'Flat Fines' if welfare_diff > 0 else 'Income-Based Fines'}")

# %% [markdown]
# ## Behavioral Responses by Income Group

# %%
# Analyze by income group
analysis_flat = society_flat.analyze_by_income_group()
analysis_ib = society_ib.analyze_by_income_group()

print("\n=== BEHAVIORAL RESPONSES BY INCOME GROUP ===")
print("\nFlat Fine System:")
for group, data in analysis_flat.items():
    print(f"  {group}: hours={data['avg_hours']:.0f}, speeding={data['avg_speeding']:.4f}")

print("\nIncome-Based Fine System:")
for group, data in analysis_ib.items():
    print(f"  {group}: hours={data['avg_hours']:.0f}, speeding={data['avg_speeding']:.4f}")

# %% [markdown]
# ## Income Inequality Effects

# %%
# Calculate Gini coefficients
gini_flat = society_flat.gini_coefficient()
gini_ib = society_ib.gini_coefficient()

print("\n=== INCOME INEQUALITY ===")
print(f"Gini coefficient (Flat Fine): {gini_flat:.4f}")
print(f"Gini coefficient (Income-Based): {gini_ib:.4f}")
print(f"Change: {(gini_ib - gini_flat) / gini_flat * 100:.1f}%")

# %% [markdown]
# ## Conclusion
#
# Our results demonstrate the trade-off between deterrence and labor market distortions in income-based fine systems. The optimal fine structure depends on:
#
# 1. **Labor supply elasticity**: Higher elasticity makes income-based fines more costly
# 2. **Existing tax rates**: Higher taxes compound the distortionary effects
# 3. **Income-speeding correlation**: Stronger correlation favors income-based targeting
