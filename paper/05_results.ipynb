# %% [markdown]
# # Results
#
# This section presents our main findings on the welfare effects of income-based versus flat traffic fine systems. We find that **flat fines are modestly more efficient** than income-based fines due to labor supply distortions, and that the optimal joint policy is essentially a pure flat fine.

# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt

from traffic_fines.core import Agent, Society, FlatFine, IncomeBasedFine
from traffic_fines.core.fines import FineStructure

np.random.seed(42)
plt.rcParams['figure.dpi'] = 150
plt.rcParams['font.size'] = 11

# Hybrid fine structure for joint optimization
class HybridFine(FineStructure):
    """Hybrid fine: flat + income-based component."""
    def __init__(self, flat_amount: float, income_rate: float):
        self.flat_amount = flat_amount
        self.income_rate = income_rate
    
    def calculate(self, income: float, speeding: float) -> float:
        return max(0, (self.flat_amount + self.income_rate * income) * speeding)
    
    def marginal_rate(self, income: float, speeding: float) -> float:
        return self.income_rate * speeding

# %% [markdown]
# ## Calibration
#
# We calibrate our model using Finnish institutional data:
# - **Income distribution**: Log-normal with mean ~€50k annual (€25/hour)
# - **Tax rate**: 40% (Finnish average marginal rate)
# - **Externality factor**: 0.2 (calibrated to match Finnish fine levels ~€500)
# - **Labor disutility**: 25.0 (produces interior labor supply solutions)

# %%
# Generate Finnish-calibrated income distribution
n_agents = 50
wages = np.random.lognormal(np.log(25.0) - 0.25, 0.5, n_agents)
wages = np.clip(wages, 10, 200)

# Model parameters
LABOR_DISUTILITY = 25.0
SPEEDING_UTILITY = 0.5
EXTERNALITY_FACTOR = 0.2
TAX_RATE = 0.4

print(f"Income Distribution (n={n_agents}):")
print(f"  Mean wage: €{np.mean(wages):.1f}/hour (annual ~€{np.mean(wages)*2000:,.0f})")
print(f"  Median wage: €{np.median(wages):.1f}/hour")
print(f"  10th percentile: €{np.percentile(wages, 10):.1f}/hour")
print(f"  90th percentile: €{np.percentile(wages, 90):.1f}/hour")

# %% [markdown]
# ## Main Result: Welfare Comparison
#
# We compare four policy regimes:
# 1. **No fine** (baseline)
# 2. **Optimal pure flat fine**
# 3. **Optimal pure income-based fine**
# 4. **Optimal hybrid** (flat + income rate, jointly optimized)

# %%
def make_agents():
    return [Agent(wage=w, labor_disutility=LABOR_DISUTILITY, 
                  speeding_utility=SPEEDING_UTILITY) for w in wages]

def evaluate_policy(fine, label=""):
    agents = make_agents()
    society = Society(agents, fine, tax_rate=TAX_RATE, externality_factor=EXTERNALITY_FACTOR)
    res = society.simulate(max_iterations=20)
    return {
        'welfare': res['social_welfare'],
        'speeding': res['avg_speeding'],
        'hours': np.mean([a.optimal_hours for a in agents]),
        'externality': res['externality_cost'],
        'gini': society.gini_coefficient()
    }

# 1. No fine baseline
no_fine = evaluate_policy(FlatFine(0))

# 2. Grid search for optimal pure flat
best_flat = None
for f in range(0, 2000, 50):
    res = evaluate_policy(FlatFine(f))
    if best_flat is None or res['welfare'] > best_flat['welfare']:
        best_flat = {**res, 'amount': f}

# 3. Grid search for optimal pure income-based
best_ib = None
for r in np.arange(0, 0.10, 0.005):
    res = evaluate_policy(IncomeBasedFine(r))
    if best_ib is None or res['welfare'] > best_ib['welfare']:
        best_ib = {**res, 'rate': r}

print("=" * 60)
print("WELFARE COMPARISON")
print("=" * 60)
print(f"\n{'Policy':<30} {'Welfare':>10} {'Speeding':>10} {'Hours':>8}")
print("-" * 60)
print(f"{'No fine':<30} {no_fine['welfare']:>10.2f} {no_fine['speeding']*100:>9.1f}% {no_fine['hours']:>8.0f}")
print(f"{'Optimal flat (€' + str(best_flat['amount']) + ')':<30} {best_flat['welfare']:>10.2f} {best_flat['speeding']*100:>9.1f}% {best_flat['hours']:>8.0f}")
print(f"{'Optimal IB (' + f"{best_ib['rate']*100:.1f}" + '%)':<30} {best_ib['welfare']:>10.2f} {best_ib['speeding']*100:>9.1f}% {best_ib['hours']:>8.0f}")

# %% [markdown]
# ## Joint Optimization: Hybrid Fine Structure
#
# We now optimize over both the flat component and income rate jointly, considering:
# 1. **Non-negative income rate** (realistic policy constraint)
# 2. **Unconstrained** (allowing negative/regressive income rates)

# %%
def evaluate_hybrid(params, allow_negative=False):
    flat, rate = params
    if flat < 0:
        return 1e10
    if not allow_negative and rate < 0:
        return 1e10
    agents = make_agents()
    society = Society(agents, HybridFine(flat, rate), 
                      tax_rate=TAX_RATE, externality_factor=EXTERNALITY_FACTOR)
    return -society.simulate(max_iterations=20)['social_welfare']

# Grid search for joint optimum (constrained: rate >= 0)
print("\n" + "=" * 60)
print("JOINT OPTIMIZATION: HYBRID FINE (Flat + Income Rate)")
print("=" * 60)

best_constrained = None
best_unconstrained = None

for flat in range(0, 1500, 100):
    for rate in np.arange(-0.10, 0.11, 0.01):
        agents = make_agents()
        society = Society(agents, HybridFine(flat, rate),
                          tax_rate=TAX_RATE, externality_factor=EXTERNALITY_FACTOR)
        res = society.simulate(max_iterations=20)
        
        # Unconstrained
        if best_unconstrained is None or res['social_welfare'] > best_unconstrained['welfare']:
            best_unconstrained = {'flat': flat, 'rate': rate, 'welfare': res['social_welfare'],
                                   'speeding': res['avg_speeding'], 
                                   'hours': np.mean([a.optimal_hours for a in agents])}
        
        # Constrained (rate >= 0)
        if rate >= 0:
            if best_constrained is None or res['social_welfare'] > best_constrained['welfare']:
                best_constrained = {'flat': flat, 'rate': rate, 'welfare': res['social_welfare'],
                                     'speeding': res['avg_speeding'],
                                     'hours': np.mean([a.optimal_hours for a in agents])}

print(f"\nConstrained (income rate >= 0):")
print(f"  Optimal: €{best_constrained['flat']} flat + {best_constrained['rate']*100:.1f}% income rate")
print(f"  Welfare: {best_constrained['welfare']:.2f}")
print(f"  Speeding: {best_constrained['speeding']*100:.1f}%")

print(f"\nUnconstrained (allowing negative income rate):")
print(f"  Optimal: €{best_unconstrained['flat']} flat + {best_unconstrained['rate']*100:.1f}% income rate")
print(f"  Welfare: {best_unconstrained['welfare']:.2f}")
print(f"  Speeding: {best_unconstrained['speeding']*100:.1f}%")

if best_unconstrained['rate'] < 0:
    print(f"\n*** The unconstrained optimum is REGRESSIVE (negative income rate) ***")

# %% [markdown]
# ## Key Finding: Flat Fines Are Optimal
#
# When constrained to non-negative income rates (the realistic policy space), the optimal policy is essentially a **pure flat fine**. The income-based component adds no value and in fact reduces welfare by distorting labor supply.

# %%
print("=" * 60)
print("SUMMARY OF RESULTS")
print("=" * 60)

results = [
    ('No fine', no_fine['welfare'], no_fine['speeding']),
    (f'Optimal flat (€{best_flat["amount"]})', best_flat['welfare'], best_flat['speeding']),
    (f'Optimal IB ({best_ib["rate"]*100:.1f}%)', best_ib['welfare'], best_ib['speeding']),
    (f'Hybrid constrained', best_constrained['welfare'], best_constrained['speeding']),
    (f'Hybrid unconstrained', best_unconstrained['welfare'], best_unconstrained['speeding']),
]

print(f"\n{'Policy':<30} {'Welfare':>10} {'Speeding':>10}")
print("-" * 50)
for name, w, s in sorted(results, key=lambda x: -x[1]):
    print(f"{name:<30} {w:>10.2f} {s*100:>9.1f}%")

print("\n" + "=" * 60)
print("POLICY IMPLICATIONS")
print("=" * 60)
print("""
1. FLAT FINES WIN: Among realistic policies (non-negative income rates),
   pure flat fines maximize social welfare.

2. LABOR SUPPLY MATTERS: Income-based fines reduce labor supply by
   creating an implicit marginal tax, which paradoxically INCREASES
   speeding (lower income = lower fines = less deterrence).

3. REGRESSIVE WOULD BE BETTER: The unconstrained optimum has negative
   income rates (higher earners pay less), but this is politically
   infeasible.

4. WELFARE GAINS ARE MODEST: The difference between optimal and
   suboptimal policies is small (~0.3-0.5 utils), suggesting that
   fine structure matters less than commonly assumed.
""")

# %% [markdown]
# ## Distributional Analysis
#
# We examine how different fine structures affect behavior across income groups.

# %%
# Compare distributional effects
agents_flat = make_agents()
agents_ib = make_agents()

soc_flat = Society(agents_flat, FlatFine(best_flat['amount']), 
                   tax_rate=TAX_RATE, externality_factor=EXTERNALITY_FACTOR)
soc_ib = Society(agents_ib, IncomeBasedFine(best_ib['rate']),
                 tax_rate=TAX_RATE, externality_factor=EXTERNALITY_FACTOR)

soc_flat.simulate()
soc_ib.simulate()

analysis_flat = soc_flat.analyze_by_income_group()
analysis_ib = soc_ib.analyze_by_income_group()

print("=" * 60)
print("BEHAVIORAL RESPONSES BY INCOME GROUP")
print("=" * 60)

print(f"\n{'Group':<15} {'Flat Fine':^25} {'Income-Based':^25}")
print(f"{'':15} {'Speed':>10} {'Hours':>10} {'Speed':>10} {'Hours':>10}")
print("-" * 65)

for group in ['bottom_20', 'middle_60', 'top_20']:
    if group in analysis_flat and group in analysis_ib:
        f = analysis_flat[group]
        i = analysis_ib[group]
        print(f"{group:<15} {f['avg_speeding']*100:>9.1f}% {f['avg_hours']:>10.0f} {i['avg_speeding']*100:>9.1f}% {i['avg_hours']:>10.0f}")

print(f"\nGini coefficient (Flat):       {soc_flat.gini_coefficient():.4f}")
print(f"Gini coefficient (Income-Based): {soc_ib.gini_coefficient():.4f}")

# %% [markdown]
# ## Conclusion
#
# Our calibrated model produces the following key findings:
#
# 1. **Optimal policy**: A flat fine of approximately €700 maximizes social welfare when income-based rates are constrained to be non-negative.
#
# 2. **Welfare ranking**: No fine < Income-based < **Flat fine** (best)
#
# 3. **Labor supply channel**: Income-based fines create an implicit marginal tax that distorts labor supply, reducing work hours and paradoxically *increasing* speeding.
#
# 4. **Distributional effects**: Income-based fines are more regressive in their behavioral effects (low earners speed more) even though they're progressive in their direct incidence.
#
# 5. **Policy robustness**: The welfare differences between policies are modest (~0.3-0.5 utils), suggesting fine structure is less important than enforcement intensity or other policy levers.
